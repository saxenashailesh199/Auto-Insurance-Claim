# %%
import numpy as np

# %%
import pandas as pd
df=pd.read_csv("Auto_Insurance_Claims_amount.csv")

# %%
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
def missing_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Missing Values'})
        mz_table['Attributes'] = df.nunique()
        mz_table['Data Type'] = df.dtypes
        
        mz_table = mz_table.sort_values('Data Type', ascending=False).round(1)
        
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
               )

        return mz_table

missing_values_table(df)
# Out:
# Your selected dataframe has 26 columns and 9134 Rows.
#                                Zero Values  Missing Values  \
# Customer                                 0               0
# Gender                                   0               0
# Vehicle Class                            0               0
# Sales Channel                            0               0
# Claim Reason                             0               0
# Policy                                   0               0
# Policy Type                              0               0
# Country                                  0               0
# Location Code                            0               0
# Marital Status                           0               0
# EmploymentStatus                         0               0
# Effective To Date                        0               0
# Education                                0               0
# Coverage                                 0               0
# ...

# %%
df.drop(columns=["Customer"],inplace=True)

# %%
#Lets chcek the value counts of object type columns
for col in df.columns:
    if df[col].dtype=="object":
        print(df[col].value_counts())
        print()
# Out:
# US    9134
# Name: Country, dtype: int64
#
# MO    3150
# IA    2601
# NE    1703
# OK     882
# KS     798
# Name: State Code, dtype: int64
#
# Missouri    3150
# Iowa        2601
# Nebraska    1703
# Oklahoma     882
# Kansas       798
# Name: State, dtype: int64
#
# No     7826
# Yes    1308
# Name: Response, dtype: int64
#
# Basic       5568
# Extended    2742
# Premium      824
# Name: Coverage, dtype: int64
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64
#
# 1/10/11    195
# 1/27/11    194
# 2/14/11    186
# 1/26/11    181
# 1/17/11    180
# 1/19/11    179
# 1/31/11    178
# 1/3/11     178
# 1/20/11    173
# 1/28/11    169
# 2/26/11    169
# 2/19/11    168
# 2/27/11    167
# 1/5/11     167
# 1/11/11    166
# 2/4/11     164
# 2/10/11    161
# 2/28/11    161
# 1/2/11     160
# 1/21/11    160
# 1/29/11    160
# 2/5/11     158
# ...

# %%
df.drop(columns=['Effective To Date','State Code','Country'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtype=="object":
        df[col]=LabelEncoder().fit_transform(df[col])

# %%
df.head(10)
# Out:
#    State  Claim Amount  Response  Coverage  Education  EmploymentStatus  \
# 0      1    276.351928         0         0          0                 1
# 1      3    697.953590         0         1          0                 4
# 2      4   1288.743165         0         2          0                 1
# 3      2    764.586183         0         0          0                 4
# 4      1    281.369258         0         0          0                 1
# 5      0    825.629780         1         0          0                 1
# 6      0    538.089864         1         0          1                 1
# 7      3    721.610031         0         2          4                 4
# 8      0   2412.750402         1         0          0                 2
# 9      0    738.817808         0         1          1                 1
#
#    Gender  Income  Location Code  Marital Status  ...  \
# 0       0   56274              1               1  ...
# 1       0       0              1               2  ...
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,101):
        X_train, X_test, y_train, y_test = train_test_split(x, y,random_state= r_state,test_size=0.20)
    
        regr.fit(X_train,y_train)

        y_pred = regr.predict(X_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2_score corresponding to random state:",r_state," is:",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2 score corresponding to ", final_r_state," is ", max_r_score)
    return final_r_state

# %%
x = df.drop(['Claim Amount'],axis=1)
y = df['Claim Amount']

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
r_state = maxr2_score(dt,x,y)
# Out:
# r2_score corresponding to random state: 42  is: 0.43942549403644304
# r2_score corresponding to random state: 43  is: 0.571762223121374
# r2_score corresponding to random state: 44  is: 0.47754845087758524
# r2_score corresponding to random state: 45  is: 0.3636542272999893
# r2_score corresponding to random state: 46  is: 0.5355504968468656
# r2_score corresponding to random state: 47  is: 0.405767898494073
# r2_score corresponding to random state: 48  is: 0.3989269314093876
# r2_score corresponding to random state: 49  is: 0.5160068205818882
# r2_score corresponding to random state: 50  is: 0.5299371455176272
# r2_score corresponding to random state: 51  is: 0.41129461741350193
# r2_score corresponding to random state: 52  is: 0.40851581817646965
# r2_score corresponding to random state: 53  is: 0.3943975258724234
# r2_score corresponding to random state: 54  is: 0.36998437617547
# r2_score corresponding to random state: 55  is: 0.4115015688535375
# ...

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
rtr = RandomForestRegressor()
r_state = maxr2_score(rtr,x,y)
# Out:
# r2_score corresponding to random state: 42  is: 0.6835248361469524
# r2_score corresponding to random state: 43  is: 0.7116246870823428
# r2_score corresponding to random state: 44  is: 0.6777006264748193
# r2_score corresponding to random state: 45  is: 0.7094138931117757
# r2_score corresponding to random state: 46  is: 0.6984032409884114
# r2_score corresponding to random state: 47  is: 0.7262526483749447
# r2_score corresponding to random state: 48  is: 0.7145862957641114
# r2_score corresponding to random state: 49  is: 0.7105189218523822
# r2_score corresponding to random state: 50  is: 0.6923450862538405
# r2_score corresponding to random state: 51  is: 0.682724779233723
# r2_score corresponding to random state: 52  is: 0.6763759211075833
# r2_score corresponding to random state: 53  is: 0.6725278749301256
# r2_score corresponding to random state: 54  is: 0.6839644466642769
# r2_score corresponding to random state: 55  is: 0.6941252577243991
# ...

# %% [markdown]
# # LGBM Regressor

# %%
#to find random stat which gives least
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    min_rmse_score=100
    for r_state in range(42,52):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        rmse_scr=np.sqrt(mean_squared_error(y_test,y_pred))
        print("RMSE corresponding to ",r_state," is ",rmse_scr)
        if rmse_scr<min_rmse_score:
            min_rmse_score=rmse_scr
            final_r_state=r_state
    print("min RMSE corresponding to ",final_r_state," is ",min_rmse_score)
    return final_r_state

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
lg = lgb.LGBMRegressor(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="r2")
grid_search.fit(x,y)
grid_search.best_params_
# Out:
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 885
# [LightGBM] [Info] Number of data points in the train set: 9134, number of used features: 21
# [LightGBM] [Info] Start training from score 800.494048
# {'learning_rate': 0.01,
#  'max_depth': 25,
#  'n_estimators': 200,
#  'num_leaves': 300}

# %%
#LGBM also give provision to define which all columns should be treated as categorical
#So we will use above provision and see what is the result
import warnings
warnings.filterwarnings("ignore")
params={'learning_rate': 0.01,'max_depth': 25,'n_estimators': 200,'num_leaves': 300}

max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2 score corresponding to ",r_state," is ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
# Out:
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001764 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 878
# [LightGBM] [Info] Number of data points in the train set: 7307, number of used features: 21
# [LightGBM] [Info] Start training from score 802.278940
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Lets make lgbm as our final model
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 87,test_size=0.20)
d_train = lgb.Dataset(x_train, label=y_train)
lgb_model = lgb.train(params, d_train)
y_pred = lgb_model.predict(x_test)
# Out:
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001733 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 874
# [LightGBM] [Info] Number of data points in the train set: 7307, number of used features: 21
# [LightGBM] [Info] Start training from score 804.180237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
rmse_scr=np.sqrt(mean_squared_error(y_test,y_pred))
print("RMSE correspondingis ",rmse_scr)
print("r2 score is ",r2_score(y_test,y_pred))
# Out:
# RMSE correspondingis  339.89660550447036
# r2 score is  0.7312084186749397

# %%
#Applying model on the test set
auto_insurance_claim_pred=lgb_model.predict(x_test)

# %%
#storing predictions as dataFrame
auto_insurance_claim_pred=pd.DataFrame(auto_insurance_claim_pred,columns=["auto_insurance_claim_amount"])

# %%
#Storing results as csv
auto_insurance_claim_pred.to_csv("auto_insurance_claim_pred.csv",index=False)
